# %%
import engine

# %%
a = engine.Value(1, label="a")
b = engine.Value(2, label="b")
c = engine.Value(4, label="c")
d = a + b; d.label = "d"
e = c * d; e.label = "e"
# 12 = 4 * (1 + 2)
e
# Out:
# Value(data=12.0)

# %%
e.backward()

# %%
engine.draw_dot(e)
